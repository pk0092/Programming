# %%
import win32com.client as wc
excel = wc.Dispatch("Excel.Application")
ex1=excel.Workbooks.Open(r'C:\Users\Min\Downloads\업무\임시고장키워드.xlsx')
ws1= ex1.ActiveSheet

NAME1=[]
NAME2=[]

for i in range(1,36207):
    NAME1 = NAME1 + [ws1.Cells(i,1).Value]
    
for item in NAME1:
    if type(item) is str:
        
        #장비문제

        if '오븐' in item:
            NAME2=NAME2+['오븐']
        elif 'oven' in item:
            NAME2=NAME2+['오븐']

        elif '센서' in item:
            NAME2=NAME2+['센서']
        elif 'SENSOR' in item:
            NAME2=NAME2+['센서']
        elif 'sensor' in item:
            NAME2=NAME2+['센서']
        elif 'Sensor' in item:
            NAME2=NAME2+['센서']

        elif '값' in item:
            NAME2=NAME2+['파라미터']
        elif '파라미터' in item:
            NAME2=NAME2+['파라미터']
        elif 'parameter' in item:
            NAME2=NAME2+['파라미터']

        elif '광학센터링' in item:
            NAME2=NAME2+['광학센터링']

        elif '릴' in item:
            NAME2=NAME2+['릴']
        elif '톱니' in item:
            NAME2=NAME2+['릴']

        elif '그리드' in item:
            NAME2=NAME2+['그리드']
        elif 'grid' in item:
            NAME2=NAME2+['그리드']

        elif '구리스' in item:
            NAME2=NAME2+['구리스']

        elif '극성' in item:
            NAME2=NAME2+['극성']

        elif '클램프' in item:
            NAME2=NAME2+['클램프']

        elif '라벨' in item:
            NAME2=NAME2+['라벨']
        elif '글씨' in item:
            NAME2=NAME2+['라벨']
        elif '바코드' in item:
            NAME2=NAME2+['라벨']
        elif 'barc' in item:
            NAME2=NAME2+['라벨']
        elif 'Barc' in item:
            NAME2=NAME2+['라벨']

        elif '벨트' in item:
            NAME2=NAME2+['벨트']
        elif 'belt' in item:
            NAME2=NAME2+['벨트']

        elif '지그' in item:
            NAME2=NAME2+['지그']
        elif 'jig' in item:
            NAME2=NAME2+['지그']
        elif 'JIG' in item:
            NAME2=NAME2+['지그']
        elif 'ZIG' in item:
            NAME2=NAME2+['지그']

        elif '나사' in item:
            NAME2=NAME2+['나사']
        elif '볼트' in item:
            NAME2=NAME2+['나사']
        elif '너트' in item:
            NAME2=NAME2+['나사']

        elif '나이프' in item:
            NAME2=NAME2+['나이프']
        elif 'knife' in item:
            NAME2=NAME2+['나이프']

        elif '날개' in item:
            NAME2=NAME2+['날개']

        elif '납' in item:
            NAME2=NAME2+['납']

        elif '다이오드' in item:
            NAME2=NAME2+['다이오드']
        elif 'diode' in item:
            NAME2=NAME2+['다이오드']

        elif '노즐' in item:
            NAME2=NAME2+['노즐']
        elif 'noz' in item:
            NAME2=NAME2+['노즐']
        elif '노즈' in item:
            NAME2=NAME2+['노즐']
        elif 'NOZ' in item:
            NAME2=NAME2+['피더']

        elif '피더' in item:
            NAME2=NAME2+['피더']
        elif 'feeder' in item:
            NAME2=NAME2+['피더']
        elif 'FEED' in item:
            NAME2=NAME2+['피더']
        elif 'fider' in item:
            NAME2=NAME2+['피더']
        elif '피딩' in item:
            NAME2=NAME2+['피더']

        elif '청소' in item:
            NAME2=NAME2+['청소']
        elif 'clean' in item:
            NAME2=NAME2+['청소']

        elif '코팅' in item:
            NAME2=NAME2+['코팅']
        elif 'coating' in item:
            NAME2=NAME2+['코팅']

        elif '솔더' in item:
            NAME2=NAME2+['솔더']
        elif 'Solder' in item:
            NAME2=NAME2+['솔더']
        elif 'solder' in item:
            NAME2=NAME2+['솔더']
        elif '플럭스' in item:
            NAME2=NAME2+['솔더']
        elif 'flux' in item:
            NAME2=NAME2+['솔더']

        elif '재시작' in item:
            NAME2=NAME2+['재시작']
        elif '장비전원리셋' in item:
            NAME2=NAME2+['재시작']
        elif 'RESET' in item:
            NAME2=NAME2+['재시작']
        elif 'Reset' in item:
            NAME2=NAME2+['재시작']
        elif 'reset' in item:
            NAME2=NAME2+['재시작']
        elif 'ON' in item:
            NAME2=NAME2+['재시작']
        elif 'On' in item:
            NAME2=NAME2+['재시작']
        elif 'on' in item:
            NAME2=NAME2+['재시작']
        elif 'OFF' in item:
            NAME2=NAME2+['재시작']
        elif 'off' in item:
            NAME2=NAME2+['재시작']
        elif '리셋' in item:
            NAME2=NAME2+['재시작']
        elif '초기화' in item:
            NAME2=NAME2+['재시작']
        elif '리세' in item:
            NAME2=NAME2+['재시작']
        elif '리스타트' in item:
            NAME2=NAME2+['재시작']

        elif '프로' in item:
            NAME2=NAME2+['프로그램']
        elif 'Prog' in item:
            NAME2=NAME2+['프로그램']
        elif 'prog' in item:
            NAME2=NAME2+['프로그램']

        elif '육안' in item:
            NAME2=NAME2+['육안']

        elif '케이블' in item:
            NAME2=NAME2+['케이블']
        elif '캐이블' in item:
            NAME2=NAME2+['케이블']
        elif 'Cable' in item:
            NAME2=NAME2+['케이블']
        elif 'cable' in item:
            NAME2=NAME2+['케이블']

        elif '픽업' in item:
            NAME2=NAME2+['픽업']
        elif 'pick' in item:
            NAME2=NAME2+['픽업']

        elif '모터' in item:
            NAME2=NAME2+['모터']
        elif 'motor' in item:
            NAME2=NAME2+['모터']
        elif 'Motor' in item:
            NAME2=NAME2+['모터']

        elif '이미지' in item:
            NAME2=NAME2+['이미지']
        elif 'image' in item:
            NAME2=NAME2+['이미지']

        elif '비전' in item:
            NAME2=NAME2+['비전']
        elif '비젼' in item:
            NAME2=NAME2+['비전']
        elif 'Visi' in item:
            NAME2=NAME2+['비전']
        elif 'visi' in item:
            NAME2=NAME2+['비전']

        elif '밸브' in item:
            NAME2=NAME2+['밸브']
        elif 'valve' in item:
            NAME2=NAME2+['밸브']
        elif 'valve' in item:
            NAME2=NAME2+['밸브']
        elif '벨브' in item:
            NAME2=NAME2+['벨브']

        elif '브러쉬' in item:
            NAME2=NAME2+['브러쉬']
        elif '브러시' in item:
            NAME2=NAME2+['브러쉬']
        elif 'brush' in item:
            NAME2=NAME2+['브러쉬']

        elif '챔버' in item:
            NAME2=NAME2+['챔버']
        elif 'chamber' in item:
            NAME2=NAME2+['챔버']

        elif '파레트' in item:
            NAME2=NAME2+['파레트']
        elif '파렛트' in item:
            NAME2=NAME2+['파레트']
        elif '팔레트' in item:
            NAME2=NAME2+['파레트']
        elif '빠레트' in item:
            NAME2=NAME2+['파레트']
        elif '빠렛트' in item:
            NAME2=NAME2+['파레트']

        elif '판넬' in item:
            NAME2=NAME2+['판넬']
        elif 'pan' in item:
            NAME2=NAME2+['판넬']
        elif 'PAN' in item:
            NAME2=NAME2+['판넬']
        elif 'Pan' in item:
            NAME2=NAME2+['판넬']
        elif 'P/N' in item:
            NAME2=NAME2+['판넬']
        elif 'pan' in item:
            NAME2=NAME2+['판넬']

        elif '코일' in item:
            NAME2=NAME2+['코일']
        elif 'coil' in item:
            NAME2=NAME2+['코일']

        elif '컨베이어' in item:
            NAME2=NAME2+['컨베이어']
        elif 'conv' in item:
            NAME2=NAME2+['컨베이어']
        elif '켄베' in item:
            NAME2=NAME2+['컨베이어']
        elif 'Conv' in item:
            NAME2=NAME2+['컨베이어']

        elif '커버' in item:
            NAME2=NAME2+['커버']
        elif 'cover' in item:
            NAME2=NAME2+['커버']

        elif '컨트롤' in item:
            NAME2=NAME2+['컨트롤']
        elif 'contr' in item:
            NAME2=NAME2+['컨트롤']

        elif '클램퍼' in item:
            NAME2=NAME2+['클램퍼']
        elif '클램프' in item:
            NAME2=NAME2+['클램퍼']
        elif 'clamp' in item:
            NAME2=NAME2+['클램퍼']

        elif '클린칭' in item:
            NAME2=NAME2+['클린칭']
        elif 'clin' in item:
            NAME2=NAME2+['클린칭']

        elif '톱니' in item:
            NAME2=NAME2+['톱니']

        elif '투입' in item:
            NAME2=NAME2+['투입']

        elif '패드' in item:
            NAME2=NAME2+['패드']
        elif 'pad' in item:
            NAME2=NAME2+['패드']

        elif '폭' in item:
            NAME2=NAME2+['폭']

        elif '퓨즈' in item:
            NAME2=NAME2+['퓨즈']
        elif 'fuse' in item:
            NAME2=NAME2+['퓨즈']

        elif '프린터' in item:
            NAME2=NAME2+['프린터']
        elif 'print' in item:
            NAME2=NAME2+['프린터']

        elif '하우징' in item:
            NAME2=NAME2+['하우징']
        elif 'Hous' in item:
            NAME2=NAME2+['하우징']
        elif 'hous' in item:
            NAME2=NAME2+['하우징']

        elif '피듀셜' in item:
            NAME2=NAME2+['피두셜']
        elif '피두셜' in item:
            NAME2=NAME2+['피두셜']
        elif 'fidu' in item:
            NAME2=NAME2+['피두셜']
        elif '피듀설' in item:
            NAME2=NAME2+['피두셜']
        elif 'Fidu' in item:
            NAME2=NAME2+['피두셜']

        elif '플런져' in item:
            NAME2=NAME2+['플런져']
        elif '플런저' in item:
            NAME2=NAME2+['플런져']
        elif '플란저' in item:
            NAME2=NAME2+['플런져']
        elif '플란져' in item:
            NAME2=NAME2+['플런져']
        elif 'Plung' in item:
            NAME2=NAME2+['플런져']
        elif 'plung' in item:
            NAME2=NAME2+['플런져']
        elif 'pLUNG' in item:
            NAME2=NAME2+['플런져']
        elif 'PLUNG' in item:
            NAME2=NAME2+['플런져']
        elif '블란자' in item:
            NAME2=NAME2+['플런져']
        elif '플련져' in item:
            NAME2=NAME2+['플런져']

        elif '소켓' in item:
            NAME2=NAME2+['소켓']
        elif 'SOCK' in item:
            NAME2=NAME2+['소켓']
        elif 'sock' in item:
            NAME2=NAME2+['소켓']
        elif 'Sock' in item:
            NAME2=NAME2+['소켓']
        elif '쇼켓' in item:
            NAME2=NAME2+['소켓']
        elif '속켓' in item:
            NAME2=NAME2+['소켓']

        elif '렉' in item:
            NAME2=NAME2+['매거진']
        elif '랙' in item:
            NAME2=NAME2+['매거진']
        elif 'wra' in item:
            NAME2=NAME2+['매거진']
        elif '캐리어' in item:
            NAME2=NAME2+['매거진']
        elif 'carrier' in item:
            NAME2=NAME2+['매거진']
        elif '매거진' in item:
            NAME2=NAME2+['매거진']
        elif 'magazine' in item:
            NAME2=NAME2+['매거진']
        elif '메거진' in item:
            NAME2=NAME2+['매거진']
        elif 'megazine' in item:
            NAME2=NAME2+['매거진']


        elif '진공' in item:
            NAME2=NAME2+['베큠']
        elif '베큠' in item:
            NAME2=NAME2+['베큠']
        elif 'vacc' in item:
            NAME2=NAME2+['베큠']
        elif 'Vacc' in item:
            NAME2=NAME2+['베큠']

        elif '호일' in item:
            NAME2=NAME2+['호일']
        elif '포일' in item:
            NAME2=NAME2+['호일']
        elif 'foil' in item:
            NAME2=NAME2+['호일']
        elif 'Foil' in item:
            NAME2=NAME2+['호일']

        elif '세그먼트' in item:
            NAME2=NAME2+['세그먼트']
        elif 'segm' in item:
            NAME2=NAME2+['세그먼트']
        elif 'SEGM' in item:
            NAME2=NAME2+['세그먼트']
        elif 'Segm' in item:
            NAME2=NAME2+['세그먼트']

        elif '스크류' in item:
            NAME2=NAME2+['스크류']
        elif 'Screw' in item:
            NAME2=NAME2+['스크류']
        elif 'screw' in item:
            NAME2=NAME2+['스크류']

        elif '스텐실' in item:
            NAME2=NAME2+['스텐실']
        elif 'stenc' in item:
            NAME2=NAME2+['스텐실']
        elif 'Stenc' in item:
            NAME2=NAME2+['스텐실']

        elif '실리콘' in item:
            NAME2=NAME2+['실리콘']
        elif 'sili' in item:
            NAME2=NAME2+['실리콘']
        elif 'Sili' in item:
            NAME2=NAME2+['실리콘']

        elif '진동' in item:
            NAME2=NAME2+['진동']
        elif '바이브' in item:
            NAME2=NAME2+['진동']
        elif 'vibr' in item:
            NAME2=NAME2+['진동']
        elif 'vivr' in item:
            NAME2=NAME2+['진동']
        elif 'vive' in item:
            NAME2=NAME2+['진동']

        elif '히트' in item:
            NAME2=NAME2+['히트']
        elif 'heat' in item:
            NAME2=NAME2+['히트']
        elif 'Heat' in item:
            NAME2=NAME2+['히트']
        elif '히팅' in item:
            NAME2=NAME2+['히트']
        elif '히터' in item:
            NAME2=NAME2+['히트']
        elif 'Hot' in item:
            NAME2=NAME2+['히트']

        elif '실링' in item:
            NAME2=NAME2+['실링']
        elif 'Seal' in item:
            NAME2=NAME2+['실링']
        elif 'seal' in item:
            NAME2=NAME2+['실링']

        elif '로드러너' in item:
            NAME2=NAME2+['로드러너']
        elif 'road' in item:
            NAME2=NAME2+['로드러너']
        elif 'runner' in item:
            NAME2=NAME2+['로드러너']
        elif 'Runner' in item:
            NAME2=NAME2+['로드러너']
        elif 'Road' in item:
            NAME2=NAME2+['로드러너']
        elif '로드 러너' in item:
            NAME2=NAME2+['로드러너']

        elif '갠트리' in item:
            NAME2=NAME2+['갠트리']
        elif '겐트리' in item:
            NAME2=NAME2+['갠트리']
        elif 'gant' in item:
            NAME2=NAME2+['갠트리']
        elif 'Gant' in item:
            NAME2=NAME2+['갠트리']

        elif '그리퍼' in item:
            NAME2=NAME2+['그리퍼']
        elif '그립' in item:
            NAME2=NAME2+['그리퍼']
        elif 'Grip' in item:
            NAME2=NAME2+['그리퍼']
        elif 'grip' in item:
            NAME2=NAME2+['그리퍼']

        elif '켈리브' in item:
            NAME2=NAME2+['켈리브레이션']
        elif '캘리브' in item:
            NAME2=NAME2+['켈리브레이션']
        elif 'Cali' in item:
            NAME2=NAME2+['켈리브레이션']
        elif 'CALI' in item:
            NAME2=NAME2+['켈리브레이션']
        elif 'cali' in item:
            NAME2=NAME2+['켈리브레이션']

        elif '냉매' in item:
            NAME2=NAME2+['냉매']
        elif '냉각' in item:
            NAME2=NAME2+['냉매']

        elif '프로브' in item:
            NAME2=NAME2+['프로브']
        elif 'Probe' in item:
            NAME2=NAME2+['프로브']
        elif 'probe' in item:
            NAME2=NAME2+['프로브']
        elif 'prove' in item:
            NAME2=NAME2+['프로브']

        elif '더러움' in item:
            NAME2=NAME2+['더러움']
        elif '더럽' in item:
            NAME2=NAME2+['더러움']
        elif 'dirt' in item:
            NAME2=NAME2+['더러움']
        elif 'Dirt' in item:
            NAME2=NAME2+['더러움']

        elif '그래프' in item:
            NAME2=NAME2+['그래프']
        elif 'Graph' in item:
            NAME2=NAME2+['그래프']
        elif 'graph' in item:
            NAME2=NAME2+['그래프']

        elif '테이블' in item:
            NAME2=NAME2+['표']
        elif 'table' in item:
            NAME2=NAME2+['표']
        elif 'Table' in item:
            NAME2=NAME2+['표']

        elif '도어' in item:
            NAME2=NAME2+['문']
        elif '문' in item:
            NAME2=NAME2+['문']
        elif 'door' in item:
            NAME2=NAME2+['문']
        elif 'Door' in item:
            NAME2=NAME2+['문']

        elif '드라이버' in item:
            NAME2=NAME2+['드라이버']
        elif '드라이브' in item:
            NAME2=NAME2+['드라이버']

        elif '화면' in item:
            NAME2=NAME2+['화면']
        elif '그래픽' in item:
            NAME2=NAME2+['화면']
        elif '디스플레이' in item:
            NAME2=NAME2+['화면']
        elif '디스프레이' in item:
            NAME2=NAME2+['화면']
        elif 'graphic' in item:
            NAME2=NAME2+['화면']
        elif 'displ' in item:
            NAME2=NAME2+['화면']
        elif '디스클레이' in item:
            NAME2=NAME2+['화면']
        elif '모니터' in item:
            NAME2=NAME2+['화면']
        elif '스크린' in item:
            NAME2=NAME2+['화면']
        elif 'screen' in item:
            NAME2=NAME2+['화면']

        elif '디스크' in item:
            NAME2=NAME2+['디스크']
        elif 'disk' in item:
            NAME2=NAME2+['디스크']

        elif '디스펜서' in item:
            NAME2=NAME2+['디스펜서']
        elif '디스펜스' in item:
            NAME2=NAME2+['디스펜서']
        elif '디스펜싱' in item:
            NAME2=NAME2+['디스펜서']

        elif '컴퓨터' in item:
            NAME2=NAME2+['PC']
        elif 'pc' in item:
            NAME2=NAME2+['PC']
        elif 'PC' in item:
            NAME2=NAME2+['PC']

        elif '레이져' in item:
            NAME2=NAME2+['레이져']
        elif 'laser' in item:
            NAME2=NAME2+['레이져']
        elif 'Laser' in item:
            NAME2=NAME2+['레이져']
        elif '레이저' in item:
            NAME2=NAME2+['레이져']

        elif '레일' in item:
            NAME2=NAME2+['레일']
        elif 'rail' in item:
            NAME2=NAME2+['레일']
        elif 'Rail' in item:
            NAME2=NAME2+['레일']

        elif '로더' in item:
            NAME2=NAME2+['로더']
        elif '랙' in item:
            NAME2=NAME2+['로더']
        elif 'load' in item:
            NAME2=NAME2+['로더']
        elif 'Load' in item:
            NAME2=NAME2+['로더']

        elif '리무버' in item:
            NAME2=NAME2+['리무버']
        elif '리무브' in item:
            NAME2=NAME2+['리무버']
        elif '리므부' in item:
            NAME2=NAME2+['리무버']
        elif '리므브' in item:
            NAME2=NAME2+['리무버']
        elif 'remove' in item:
            NAME2=NAME2+['리무버']
        elif 'Remove' in item:
            NAME2=NAME2+['리무버']
        elif '리부브' in item:
            NAME2=NAME2+['리무버']

        elif '한계' in item:
            NAME2=NAME2+['한계']
        elif '임계' in item:
            NAME2=NAME2+['한계']
        elif '리미트' in item:
            NAME2=NAME2+['한계']
        elif '리밋' in item:
            NAME2=NAME2+['한계']
        elif '리미티드' in item:
            NAME2=NAME2+['한계']
        elif 'limit' in item:
            NAME2=NAME2+['한계']

        elif '리본' in item:
            NAME2=NAME2+['리본']
        elif 'rebon' in item:
            NAME2=NAME2+['리본']

        elif '리젝' in item:
            NAME2=NAME2+['리젝']
        elif '리젯' in item:
            NAME2=NAME2+['리젝']
        elif 'rejec' in item:
            NAME2=NAME2+['리젝']
        elif 'Rejec' in item:
            NAME2=NAME2+['리젝']

        elif '마그네틱' in item:
            NAME2=NAME2+['자석']
        elif '자석' in item:
            NAME2=NAME2+['자석']
        elif '마그넷' in item:
            NAME2=NAME2+['자석']
        elif 'magne' in item:
            NAME2=NAME2+['자석']
        elif 'Magne' in item:
            NAME2=NAME2+['자석']

        elif '멤브레' in item:
            NAME2=NAME2+['멤브레인']
        elif '멤브래' in item:
            NAME2=NAME2+['멤브레인']
        elif 'brain' in item:
            NAME2=NAME2+['멤브레인']
        elif '멤프' in item:
            NAME2=NAME2+['멤브레인']

        elif '배출' in item:
            NAME2=NAME2+['배출']
        elif '배충' in item:
            NAME2=NAME2+['배출']
        elif '배츨' in item:
            NAME2=NAME2+['배출']
        elif '배춭' in item:
            NAME2=NAME2+['배출']
        elif '베출' in item:
            NAME2=NAME2+['배출']
        elif '배쿨' in item:
            NAME2=NAME2+['배출']

        elif '버퍼' in item:
            NAME2=NAME2+['버퍼']
        elif '버ㅓ퍼' in item:
            NAME2=NAME2+['버퍼']
        elif 'buffer' in item:
            NAME2=NAME2+['버퍼']
        elif 'Buffer' in item:
            NAME2=NAME2+['버퍼']

        elif '베어링' in item:
            NAME2=NAME2+['베어링']
        elif 'bare' in item:
            NAME2=NAME2+['베어링']
        elif 'bear' in item:
            NAME2=NAME2+['베어링']

        elif '블레이드' in item:
            NAME2=NAME2+['블레이드']
        elif '블래이드' in item:
            NAME2=NAME2+['블레이드']
        elif 'blade' in item:
            NAME2=NAME2+['블레이드']
        elif 'blade' in item:
            NAME2=NAME2+['블레이드']

        elif '비트' in item:
            NAME2=NAME2+['비트']
        elif '빗트' in item:
            NAME2=NAME2+['비트']
        elif 'bit' in item:
            NAME2=NAME2+['비트']
        elif 'Beat' in item:
            NAME2=NAME2+['비트']

        elif '스캔' in item:
            NAME2=NAME2+['스캔']
        elif '스캐너' in item:
            NAME2=NAME2+['스캔']
        elif 'Scan' in item:
            NAME2=NAME2+['스캔']
        elif 'scan' in item:
            NAME2=NAME2+['스캔']
        elif '스켄' in item:
            NAME2=NAME2+['스캔']
        elif '스케너' in item:
            NAME2=NAME2+['스캔']

        elif '스토퍼' in item:
            NAME2=NAME2+['스토퍼']
        elif 'stopper' in item:
            NAME2=NAME2+['스토퍼']
        elif 'Stopper' in item:
            NAME2=NAME2+['스토퍼']
        elif '댐퍼' in item:
            NAME2=NAME2+['스토퍼']
        elif 'damp' in item:
            NAME2=NAME2+['스토퍼']
        elif 'Damp' in item:
            NAME2=NAME2+['스토퍼']
        elif '댐핑' in item:
            NAME2=NAME2+['스토퍼']
        elif '스톱퍼' in item:
            NAME2=NAME2+['스토퍼']

        elif '실린더' in item:
            NAME2=NAME2+['실린더']
        elif 'cylin' in item:
            NAME2=NAME2+['실린더']
        elif 'Cylin' in item:
            NAME2=NAME2+['실린더']

        elif '호스' in item:
            NAME2=NAME2+['호스']
        elif '관' in item:
            NAME2=NAME2+['호스']
        elif '호수' in item:
            NAME2=NAME2+['호스']
        elif 'hose' in item:
            NAME2=NAME2+['호스']

        elif '체인' in item:
            NAME2=NAME2+['체인']
        elif 'Chain' in item:
            NAME2=NAME2+['체인']
        elif 'chain' in item:
            NAME2=NAME2+['체인']

        elif '커터' in item:
            NAME2=NAME2+['커터']
        elif '커팅' in item:
            NAME2=NAME2+['커터']
        elif '컷터' in item:
            NAME2=NAME2+['커터']
        elif '컷팅' in item:
            NAME2=NAME2+['커터']
        elif 'cutt' in item:
            NAME2=NAME2+['커터']
        elif 'Cutt' in item:
            NAME2=NAME2+['커터']

        elif '코너필' in item:
            NAME2=NAME2+['코너필']
        elif 'corner' in item:
            NAME2=NAME2+['코너필']
        elif 'Corner' in item:
            NAME2=NAME2+['코너필']

        elif '클리너' in item:
            NAME2=NAME2+['클리너']
        elif '클리어' in item:
            NAME2=NAME2+['클리너']

        elif '키보드' in item:
            NAME2=NAME2+['키보드']
        elif 'keyboard' in item:
            NAME2=NAME2+['키보드']

        elif '트윈헤드' in item:
            NAME2=NAME2+['트윈헤드']
        elif 'twin' in item:
            NAME2=NAME2+['트윈헤드']

        elif '필터' in item:
            NAME2=NAME2+['필터']
        elif 'filt' in item:
            NAME2=NAME2+['필터']
        elif 'Filt' in item:
            NAME2=NAME2+['필터']
        elif '정제' in item:
            NAME2=NAME2+['필터']

        elif '헤드' in item:
            NAME2=NAME2+['헤드']
        elif '해드' in item:
            NAME2=NAME2+['헤드']
        elif 'head' in item:
            NAME2=NAME2+['헤드']
        elif 'Head' in item:
            NAME2=NAME2+['헤드']

        elif '홀' in item:
            NAME2=NAME2+['홀']
        elif 'hole' in item:
            NAME2=NAME2+['홀']

            ################제품문제   
        elif '긁힘' in item:
            NAME2=NAME2+['긁힘']
        elif '까임' in item:
            NAME2=NAME2+['긁힘']
        elif '스크래치' in item:
            NAME2=NAME2+['긁힘']
        elif 'scratch' in item:
            NAME2=NAME2+['긁힘']
        elif '기스' in item:
            NAME2=NAME2+['긁힘']
        elif 'Scratch' in item:
            NAME2=NAME2+['긁힘']
        elif '찍' in item:
            NAME2=NAME2+['긁힘']
        elif '찎' in item:
            NAME2=NAME2+['긁힘']

        elif '뒤집' in item:
            NAME2=NAME2+['뒤집힘']

        elif '가불량' in item:
            NAME2=NAME2+['가불량']
        elif 'NTF' in item:
            NAME2=NAME2+['가불량']
        elif 'ntf' in item:
            NAME2=NAME2+['가불량']

        elif '통신' in item:
            NAME2=NAME2+['통신']

        elif '쇼트' in item:
            NAME2=NAME2+['쇼트']
        elif 'Short' in item:
            NAME2=NAME2+['쇼트']
        elif 'short' in item:
            NAME2=NAME2+['쇼트']
        elif '브릿지' in item:
            NAME2=NAME2+['쇼트']
        elif 'bridge' in item:
            NAME2=NAME2+['쇼트']

        elif '들뜸' in item:
            NAME2=NAME2+['들뜸']
        elif 'lift' in item:
            NAME2=NAME2+['들뜸']
        elif '들듬' in item:
            NAME2=NAME2+['들뜸']
        elif '들뜬' in item:
            NAME2=NAME2+['들뜸']
        elif '들떠' in item:
            NAME2=NAME2+['들뜸']
        elif '들뜨' in item:
            NAME2=NAME2+['들뜸']
        elif '리프트' in item:
            NAME2=NAME2+['들뜸']
        elif '리프팅' in item:
            NAME2=NAME2+['들뜸']

        elif '비석' in item:
            NAME2=NAME2+['비석']

        elif '틀어짐' in item:
            NAME2=NAME2+['틀어짐']

        elif '날림' in item:
            NAME2=NAME2+['날림']

        elif '미실장' in item:
            NAME2=NAME2+['미실장']

        elif '콘덴서' in item:
            NAME2=NAME2+['콘덴서']
        elif 'conden' in item:
            NAME2=NAME2+['콘덴서']
        elif '캐패시' in item:
            NAME2=NAME2+['콘덴서']
        elif 'capaci' in item:
            NAME2=NAME2+['콘덴서']
        elif '케페' in item:
            NAME2=NAME2+['콘덴서']
        elif 'Capaci' in item:
            NAME2=NAME2+['콘덴서']

        elif '제품' in item:
            NAME2=NAME2+['제품']

        elif '기포' in item:
            NAME2=NAME2+['기포']
        elif '보이드' in item:
            NAME2=NAME2+['기포']
        elif 'void' in item:
            NAME2=NAME2+['기포']

        elif 'PCB' in item:
            NAME2=NAME2+['PCB']
        elif 'pcb' in item:
            NAME2=NAME2+['pcb']

        elif '칩' in item:
            NAME2=NAME2+['칩']
        elif 'chip' in item:
            NAME2=NAME2+['칩']
        elif 'Chip' in item:
            NAME2=NAME2+['칩']
        elif 'CHIP' in item:
            NAME2=NAME2+['칩']    

        elif '자재' in item:
            NAME2=NAME2+['자재']
        elif '자제' in item:
            NAME2=NAME2+['자재']

        elif '커넥터' in item:
            NAME2=NAME2+['커넥터']
        elif '컨넥터' in item:
            NAME2=NAME2+['커넥터']
        elif 'connect' in item:
            NAME2=NAME2+['커넥터']
        elif 'Connect' in item:
            NAME2=NAME2+['커넥터']

        elif '핀' in item:
            NAME2=NAME2+['핀']
        elif 'Pin' in item:
            NAME2=NAME2+['핀']
        elif 'PIN' in item:
            NAME2=NAME2+['핀']
        elif 'pin' in item:
            NAME2=NAME2+['핀']

        elif '트랜지스터' in item:
            NAME2=NAME2+['트랜지스터']
        elif 'transi' in item:
            NAME2=NAME2+['트랜지스터']
        elif 'Transi' in item:
            NAME2=NAME2+['트랜지스터']
        elif 'TR' in item:
            NAME2=NAME2+['트랜지스터']

        elif '누수' in item:
            NAME2=NAME2+['누수']
        elif '리크' in item:
            NAME2=NAME2+['누수']
        elif 'leak' in item:
            NAME2=NAME2+['누수']
        elif '샘' in item:
            NAME2=NAME2+['누수']
        elif 'Leak' in item:
            NAME2=NAME2+['누수']
        elif '꼬리' in item:
            NAME2=NAME2+['누수']
        elif '넘침' in item:
            NAME2=NAME2+['누수']
        elif '넘쳐' in item:
            NAME2=NAME2+['누수']
        elif '넘친' in item:
            NAME2=NAME2+['누수']
        elif '누설' in item:
            NAME2=NAME2+['누수']
        elif '누유' in item:
            NAME2=NAME2+['누수']
        elif '누출' in item:
            NAME2=NAME2+['누수']

        elif '갭' in item:
            NAME2=NAME2+['갭']
        elif 'gap' in item:
            NAME2=NAME2+['갭']
        elif 'Gap' in item:
            NAME2=NAME2+['갭']
        elif 'GAP' in item:
            NAME2=NAME2+['갭']
        elif '겝' in item:
            NAME2=NAME2+['갭']

        elif '결합' in item:
            NAME2=NAME2+['결합']
        elif '합칠' in item:
            NAME2=NAME2+['결합']
        elif '체결' in item:
            NAME2=NAME2+['결합']

        elif '겹침' in item:
            NAME2=NAME2+['겹침']
        elif '겹쳐' in item:
            NAME2=NAME2+['겹침']
        elif '겹치' in item:
            NAME2=NAME2+['겹침']

        elif '경화' in item:
            NAME2=NAME2+['경화']

        elif '노후' in item:
            NAME2=NAME2+['노후']

        elif '비닐' in item:
            NAME2=NAME2+['비닐']
        elif '비늘' in item:
            NAME2=NAME2+['비닐']

        elif '깨짐' in item:
            NAME2=NAME2+['깨짐']
        elif '꺠짐' in item:
            NAME2=NAME2+['깨짐']

        elif '꺼져' in item:
            NAME2=NAME2+['꺼짐']
        elif '꺼졌' in item:
            NAME2=NAME2+['꺼짐']
        elif '꺼진' in item:
            NAME2=NAME2+['꺼짐']
        elif '꺼지' in item:
            NAME2=NAME2+['꺼짐']
        elif '꺼짐' in item:
            NAME2=NAME2+['꺼짐']
        elif '껐다' in item:
            NAME2=NAME2+['꺼짐']
        elif '껏다' in item:
            NAME2=NAME2+['꺼짐']

        elif '꺽임' in item:
            NAME2=NAME2+['꺽임']
        elif '꺾임' in item:
            NAME2=NAME2+['꺽임']

        elif '끼임' in item:
            NAME2=NAME2+['끼임']
        elif '껴서' in item:
            NAME2=NAME2+['끼임']
        elif '낌' in item:
            NAME2=NAME2+['끼임']
        elif '낀' in item:
            NAME2=NAME2+['끼임']
        elif '끼징ㅁ' in item:
            NAME2=NAME2+['끼임']
        elif '껴짐' in item:
            NAME2=NAME2+['끼임']

        elif '꼬임' in item:
            NAME2=NAME2+['꼬임']

        elif '끊김' in item:
            NAME2=NAME2+['끊김']
        elif '끈김' in item:
            NAME2=NAME2+['끊김']
        elif '끊겨' in item:
            NAME2=NAME2+['끊김']
        elif '끊어짐' in item:
            NAME2=NAME2+['끊김']
        elif '끊심' in item:
            NAME2=NAME2+['끊김']

        elif '넘어짐' in item:
            NAME2=NAME2+['넘어짐']

        elif '녹음' in item:
            NAME2=NAME2+['녹음']
        elif '녹는' in item:
            NAME2=NAME2+['녹음']
        elif '녹는' in item:
            NAME2=NAME2+['녹음']

        elif '느림' in item:
            NAME2=NAME2+['느림']
        elif '느린' in item:
            NAME2=NAME2+['느림']
        elif '느려' in item:
            NAME2=NAME2+['느림']
        elif '느리' in item:
            NAME2=NAME2+['느림']
        elif '느러' in item:
            NAME2=NAME2+['느림']
        elif 'slow' in item:
            NAME2=NAME2+['느림']
        elif 'Slow' in item:
            NAME2=NAME2+['느림']
        elif 'SLOW' in item:
            NAME2=NAME2+['느림']

        elif '도포' in item:
            NAME2=NAME2+['도포']

        elif '동일' in item:
            NAME2=NAME2+['동일']
        elif '동잃' in item:
            NAME2=NAME2+['동일']

        elif '동작' in item:
            NAME2=NAME2+['동작']
        elif '동적' in item:
            NAME2=NAME2+['동작']
        elif '동중' in item:
            NAME2=NAME2+['동작']

        elif '낙하' in item:
            NAME2=NAME2+['낙하']
        elif '떨어' in item:
            NAME2=NAME2+['낙하']
        elif '드롭' in item:
            NAME2=NAME2+['낙하']
        elif '떨이짐' in item:
            NAME2=NAME2+['낙하']
        elif '떠어짐' in item:
            NAME2=NAME2+['낙하']

        elif '램프' in item:
            NAME2=NAME2+['전구']
        elif '전구' in item:
            NAME2=NAME2+['전구']
        elif 'lamp' in item:
            NAME2=NAME2+['전구']
        elif 'Lamp' in item:
            NAME2=NAME2+['전구']

        elif '등록' in item:
            NAME2=NAME2+['등록']
        elif 'enrol' in item:
            NAME2=NAME2+['등록']
        elif 'registra' in item:
            NAME2=NAME2+['등록']

        elif '디버깅' in item:
            NAME2=NAME2+['디버깅']
        elif '디버김' in item:
            NAME2=NAME2+['디버깅']
        elif '디버그' in item:
            NAME2=NAME2+['디버깅']
        elif '디비깅' in item:
            NAME2=NAME2+['디버깅']
        elif 'Debug' in item:
            NAME2=NAME2+['디버깅']
        elif 'debug' in item:
            NAME2=NAME2+['디버깅']

        elif '로딩' in item:
            NAME2=NAME2+['로딩']
        elif 'loading' in item:
            NAME2=NAME2+['로딩']
        elif '렉' in item:
            NAME2=NAME2+['로딩']
        elif '랙' in item:
            NAME2=NAME2+['로딩']

        elif '리딩' in item:
            NAME2=NAME2+['리딩']
        elif 'read' in item:
            NAME2=NAME2+['리딩']
        elif 'Read' in item:
            NAME2=NAME2+['리딩']

        elif '모델' in item:
            NAME2=NAME2+['모델']
        elif 'model' in item:
            NAME2=NAME2+['모델']
        elif 'MODEL' in item:
            NAME2=NAME2+['모델']

        elif '미실' in item:
            NAME2=NAME2+['미실장']

        elif '수동' in item:
            NAME2=NAME2+['수동 조작']
        elif 'manual' in item:
            NAME2=NAME2+['수동 조작']
        elif 'Manual' in item:
            NAME2=NAME2+['수동 조작']
        elif '직접' in item:
            NAME2=NAME2+['수동 조작']
        elif '메뉴' in item:
            NAME2=NAME2+['수동 조작']
        elif '매뉴' in item:
            NAME2=NAME2+['수동 조작']
        elif 'manu' in item:
            NAME2=NAME2+['수동 조작']

        elif '리커버리' in item:
            NAME2=NAME2+['복구']
        elif '복구' in item:
            NAME2=NAME2+['복구']
        elif '조치' in item:
            NAME2=NAME2+['복구']
        elif 'recover' in item:
            NAME2=NAME2+['복구']
        elif 'Recover' in item:
            NAME2=NAME2+['복구']
        elif 'RECOVER' in item:
            NAME2=NAME2+['복구']
        elif '리페어' in item:
            NAME2=NAME2+['복구']
        elif 'repair' in item:
            NAME2=NAME2+['복구']
        elif 'Repair' in item:
            NAME2=NAME2+['복구']
        elif 'REPAIR' in item:
            NAME2=NAME2+['복구']

        elif '오삽' in item:
            NAME2=NAME2+['오삽']

        elif '알람' in item:
            NAME2=NAME2+['알람']
        elif '알림' in item:
            NAME2=NAME2+['알람']
        elif '알랑' in item:
            NAME2=NAME2+['알람']
        elif '알랍' in item:
            NAME2=NAME2+['알람']
        elif 'Alarm' in item:
            NAME2=NAME2+['알람']
        elif 'alarm' in item:
            NAME2=NAME2+['알람']

        elif '테스트' in item:
            NAME2=NAME2+['테스트']
        elif '샘플' in item:
            NAME2=NAME2+['테스트']
        elif '시범' in item:
            NAME2=NAME2+['테스트']
        elif '시험' in item:
            NAME2=NAME2+['테스트']
        elif 'test' in item:
            NAME2=NAME2+['테스트']
        elif 'TEST' in item:
            NAME2=NAME2+['테스트']
        elif 'Test' in item:
            NAME2=NAME2+['테스트']
        elif 'sample' in item:
            NAME2=NAME2+['테스트']
        elif 'Sample' in item:
            NAME2=NAME2+['테스트']

        else:
            NAME2=NAME2+['에러']
    else:
        NAME2=NAME2+['에러']
        
for i, name in enumerate(NAME2):
    print(name)
    ws1.Cells(i+1,3).Value = name
    
    
ex1.Save()
excel.Quit()
print("Done")
# Out:
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 비트
# 에러
# 에러
# 에러
# 에러
# 재시작
# 에러
# 에러
# 에러
# 제품
# 에러
# 실린더
# 에러
# 에러
# 에러
# 문
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 피더
# 에러
# 자재
# 에러
# 자재
# 에러
# 에러
# 에러
# 에러
# 에러
# 호일
# 재시작
# 그리퍼
# 에러
# 에러
# 에러
# 에러
# 에러
# 자재
# 에러
# 에러
# 에러
# 에러
# 에러
# PC
# 에러
# 에러
# 에러
# 에러
# 에러
# 가불량
# 에러
# 에러
# 에러
# 오븐
# 에러
# PC
# PC
# PC
# PC
# PC
# PC
# PC
# PC
# 에러
# 에러
# 재시작
# 에러
# 에러
# 에러
# 에러
# 프로브
# 청소
# 프로그램
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 스크류
# 결합
# 실링
# 실링
# 실링
# 센서
# 에러
# 에러
# 에러
# 에러
# 에러
# 솔더
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 트랜지스터
# 에러
# 쇼트
# 헤드
# 테스트
# 테스트
# 테스트
# 테스트
# 테스트
# 에러
# 에러
# 에러
# 에러
# 밸브
# 모델
# 재시작
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 피더
# 에러
# 에러
# 가불량
# 가불량
# 겹침
# 에러
# 에러
# 납
# 피더
# 에러
# 기포
# 누수
# 에러
# 끊김
# 끼임
# 납
# 납
# 납
# 에러
# 제품
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 에러
# 문
# 도포
# 동작
# 에러
# 들뜸
# 들뜸
# 에러
# 라벨
# 라벨
# 라벨
# 라벨
# 틀어짐
# 레이져
# 레일
# 레일
# 레일
# 에러
# 에러
# 에러
# 에러
# 리본
# 재시작
# 재시작
# 재시작
# 리젝
# 복구
# 릴
# 릴
# 에러
# 에러
# 에러
# 에러
# ...

# %%
import win32com.client as wc
excel = wc.Dispatch("Excel.Application")
excel.Quit()

# %%
import win32com.client as wc
excel = wc.Dispatch("Excel.Application")
ex1=excel.Workbooks.Open(r'C:\Users\uia97275\Documents\Programming\41.xlsx')
ws1= ex1.ActiveSheet

EQG=["Aging chamber","Aging test","AOI & RF test","Assembly","Automation assembly","Backend AOI","Battery Soldering","Buffer conveyor","CISS test","Coating","Coating Curing & Vision","Cobot","Coil & Leakage test","Coil height check","Cold test","Connector Screwing","Conveyor","Cooler","Cooper venturi","Cover clinching","Crash test","Curing oven","EOL","Final test","FOB Vision"," Button and packing station","Forming","Function test","Gluing","Heat sink","Heat staking","Hot chamber","Hot test","ICT","ISC test","Laser & Release test","Laser marking","Laser pin check","Laser welding","Leakage test","Metal PCB assembly","Oven","Packing","Packing & Pin check","PCB cleaner","Potting","Potting Equipment","Power tester","Pressfit","RF test","Robot Soldering","Router","Screen printer","Screwing","Sealing","Shaker test","Single pin insertion","Soldering","TIM","UPS","Venturi test","Vision","Vision & Packing","Welding","Wire bonding","자동 삽입기","Connector Pin Inspection","TG1D-Evo Automation line","Wakeup test","Fuse insertion","NNNNN"]
NAME1=[]

EQ=[]

for i in range(1,36207):
    NAME1 = NAME1 + [ws1.Cells(i,1).Value]
    
for j,item in enumerate(NAME1):
    if type(item) is str:
        item=item.lower()
        
        for k,E in enumerate(EQG):
            if type(E) is str:
                E=E.lower()
                if E in item:
                    EQ=EQ+[E]
                    break;
                elif k == len(EQG)-1:
                    if j == len(EQ):
                        EQ=EQ+["zzz"]
                else:
                    pass
                


        
for i, name in enumerate(EQ):
    print(name)
    ws1.Cells(i+1,3).Value = name
    
    
ex1.Save()
#excel.Quit()
print("Done")
# Out:
# zzz
# zzz
# ict
# single pin insertion
# single pin insertion
# zzz
# fuse insertion
# single pin insertion
# tg1d-evo automation line
# soldering
# soldering
# soldering
# pressfit
# tg1d-evo automation line
# fuse insertion
# tg1d-evo automation line
# tg1d-evo automation line
# tg1d-evo automation line
# cobot
# tg1d-evo automation line
# tg1d-evo automation line
# assembly
# single pin insertion
# single pin insertion
# ict
# assembly
# assembly
# fuse insertion
# coating
# cobot
# coating
# pressfit
# coating
# ict
# single pin insertion
# single pin insertion
# tg1d-evo automation line
# tg1d-evo automation line
# coating
# single pin insertion
# single pin insertion
# single pin insertion
# single pin insertion
# single pin insertion
# coating
# single pin insertion
# zzz
# coating
# zzz
# fuse insertion
# coating
# single pin insertion
# single pin insertion
# fuse insertion
# tg1d-evo automation line
# soldering
# coating
# fuse insertion
# tg1d-evo automation line
# ...

# %%
A=["absc","as123"]
B="s12"
C="ADSAs12"
D=[]
for i,a in enumerate(A):
    if B in C:
        print(i)
        
A=A+["absc"]
print(len(A))
print(len(D))
# Out:
# 0
# 1
# 3
# 0
