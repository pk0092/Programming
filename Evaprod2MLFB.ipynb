# %%
ALL = []
BS = []

#텍스트 파일의 내용을 한 줄 한 줄 읽어 데이터 구조를 채움
for line in open(r'C:\Users\uia97275\Documents\Programming\eva.txt'):
    ALL = ALL + [line]
print(ALL)

for lin in open(r'C:\Users\uia97275\Documents\Programming\BSMLFB.txt'):
    lines = lin.strip().split('\n') 
    BS = BS+[lines[0]]    
print(BS)
    
for n,m in enumerate(ALL):
    for b in BS:
        if b in m:
            print(m)
print("done3")
# Out:
# ['MLFB\tPCB_PART\tARRARY_SIZE\n', '0201CS\tKR77022102A\t2\n', '0201CS1\tKR77022102A\t2\n', '0202CS\tKR77022102A\t2\n', '0202CS1\tKR77022102A\t2\n', '0203BS\tKR77022103A\t2\n', '0203BS1\tKR77022103A\t2\n', '0204BS\tKR77022103A\t2\n', '0204BS1\tKR77022103A\t2\n', '0315S\tKR94012101F\t36\n', '0315S1\tKR94012101F\t36\n', '1301BS\tKR77132101C\t2\n', '1301BS1\tKR77132101C\t2\n', '1310CS\tA2C53428307\t2\n', '1310CS1\tA2C53428307\t2\n', '1311BS\tA2C53428307\t2\n', '1311BS1\tA2C53428307\t2\n', '1320AS\tA2C53428307\t2\n', '1320AS1\tA2C53428307\t2\n', '1325AS\tA2C53428307\t2\n', '1325AS1\tA2C53428307\t2\n', '1330AS\tA2C53428307\t2\n', '1330AS1\tA2C53428307\t2\n', '1330CS\tA2C96977100\t2\n', '1330CS1\tA2C96977100\t2\n', '1331AS\tA2C53428307\t2\n', '1331AS1\tA2C53428307\t2\n', '1332AS\tA2C53428307\t2\n', '1332AS1\tA2C53428307\t2\n', '1335AS\tA2C53428307\t2\n', '1335AS1\tA2C53428307\t2\n', '1340AS\tA2C53428307\t2\n', '1340AS1\tA2C53428307\t2\n', '1341CS\tA2C53428307\t2\n', '1341CS1\tA2C53428307\t2
# ...
