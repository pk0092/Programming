# %%
import win32com.client as wc
excel = wc.Dispatch("Excel.Application")
ex1=excel.Workbooks.Open(r'C:\Users\uidk3482\Documents\project\ex1.xlsx')
ex2=excel.Workbooks.Open(r'C:\Users\uidk3482\Documents\project\ex3.xlsx')

ws1= ex1.ActiveSheet
ws2= ex2.ActiveSheet

for i in range(1,len(ws1.rows)):
    APO1=ws1.Cells(i,2).Value
    EQUINUM1=ws1.Cells(i,5).Value
    WORKCENTER=ws1.Cells(i,6).Value
    MES=ws1.Cells(i,7).Value
    
    for j in range(1,len(ws2.rows)):
        APO2=ws2.Cells(j,9).Value
        EQUINUM2=ws2.Cells(j,2).Value
        if ((APO2 is APO1) and (EQUINUM2 is EQUINUM1) and (APO1 is not None) and (EQUINUM1 is not None)):
            ws2.Cells(j,13).Value=WORKCENTER
            ws2.Cells(j,14).Value=MES
            
ex2.Save()
excel.Quit()
print("Done")

# %%
import win32com.client as wc
excel = wc.Dispatch("Excel.Application")
ex1=excel.Workbooks.Open(r'C:\Users\uidk3482\Documents\project\설비내역.xlsx')
ex2=excel.Workbooks.Open(r'C:\Users\uidk3482\Documents\project\고장내역.xlsx')

ws1= ex1.ActiveSheet
ws2= ex2.ActiveSheet

LINE1=[]
EQUINUM1=[]

for i in range(1,1030):
    LINE1=LINE1+[ws1.Cells(i,8).Value]
    EQUINUM1=EQUINUM1+[ws1.Cells(i,2).Value]

for j in range(1,154134):
    if (ws2.Cells(j,4).Value in EQUINUM1):
        l=EQUINUM1.index(ws2.Cells(j,4).Value)
        ws2.Cells(j,2).Value = LINE1[l]
    else:
        pass
        
ex2.Save()
excel.Quit()
print("Done")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6e55177d6553> in <module>()
#      16 for j in range(1,154134):
#      17     if (ws2.Cells(j,4).Value in EQUINUM1):
# ---> 18         l=EQUINUM1.index(ws2.Cells(j,4).Value)
#      19         ws2.Cells(j,2).Value = LINE1[l]
#      20     else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\dynamic.py in __getattr__(self, attr)
#     522                                 raise
#     523                         debug_attr_print("OLE returned ", ret)
# --> 524                         return self._get_good_object_(ret)
#     525
#     526                 # no where else to look.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\dynamic.py in _get_good_object_(self, ob, userName, ReturnCLSID)
# ...

# %%
excel.Quit()

# %%
import win32com.client as wc
excel = wc.Dispatch("Excel.Application")
ex1=excel.Workbooks.Open(r'C:\Users\uidk3482\Documents\project\임시사용\조치자.xlsx')
ws1= ex1.ActiveSheet

Name1=[]
NAME2=[]

for i in range(2,1611):
    Name1=Name1+[ws1.Cells(i,1).Value]
    
for item in Name1:
        if '최정용' in item:
            NAME2=NAME2+['최정용']
        elif '강수지' in item:
            NAME2=NAME2+['강수지']
        elif '공진영' in item:
            NAME2=NAME2+['공진영']
        elif '곽시은' in item:
            NAME2=NAME2+['곽시은']
        elif '구본욱' in item:
            NAME2=NAME2+['구본욱']
        elif '권성경' in item:
            NAME2=NAME2+['권성경']
        elif '김다혜' in item:
            NAME2=NAME2+['김다혜']
        elif '김보배' in item:
            NAME2=NAME2+['김보배']
        elif '김선중' in item:
            NAME2=NAME2+['김선중']
        elif '김성남' in item:
            NAME2=NAME2+['김성남']
        elif '김소희' in item:
            NAME2=NAME2+['김소희']
        elif '김솔비' in item:
            NAME2=NAME2+['김솔비']
        elif '김영곤' in item:
            NAME2=NAME2+['김영곤']
        elif '김유란' in item:
            NAME2=NAME2+['김유란']
        elif '김윤수' in item:
            NAME2=NAME2+['김윤수']
        elif '김윤지' in item:
            NAME2=NAME2+['김윤지']
        elif '김형준' in item:
            NAME2=NAME2+['김형준']
        elif '박남주' in item:
            NAME2=NAME2+['박남주']
        elif '노대현' in item:
            NAME2=NAME2+['노대현']
        elif '노수진' in item:
            NAME2=NAME2+['노수진']
        elif '민경화' in item:
            NAME2=NAME2+['민경화']
        elif '민지은' in item:
            NAME2=NAME2+['민지은']
        elif '박경원' in item:
            NAME2=NAME2+['박경원']
        elif '박나미' in item:
            NAME2=NAME2+['박나미']
        elif '박민주' in item:
            NAME2=NAME2+['박민주']
        elif '박샛별' in item:
            NAME2=NAME2+['박샛별']
        elif '박순홍' in item:
            NAME2=NAME2+['박순홍']
        elif '박아영' in item:
            NAME2=NAME2+['박아영']
        elif '박일수' in item:
            NAME2=NAME2+['박일수']
        elif '박준모' in item:
            NAME2=NAME2+['박준모']
        elif '박창욱' in item:
            NAME2=NAME2+['박창욱']
        elif '박현경' in item:
            NAME2=NAME2+['박현경']
        elif '배기웅' in item:
            NAME2=NAME2+['배기웅']
        elif '봉선애' in item:
            NAME2=NAME2+['봉선애']
        elif '서원성' in item:
            NAME2=NAME2+['서원성']
        elif '서희주' in item:
            NAME2=NAME2+['서희주']
        elif '손영미' in item:
            NAME2=NAME2+['손영미']
        elif '손종식' in item:
            NAME2=NAME2+['손종식']
        elif '송명애' in item:
            NAME2=NAME2+['송명애']
        elif '송보라' in item:
            NAME2=NAME2+['송보라']
        elif '신동현' in item:
            NAME2=NAME2+['신동현']
        elif '신인규' in item:
            NAME2=NAME2+['신인규']
        elif '신현식' in item:
            NAME2=NAME2+['신현식']
        elif '신혜현' in item:
            NAME2=NAME2+['신혜현']
        elif '심용준' in item:
            NAME2=NAME2+['심용준']
        elif '정은정' in item:
            NAME2=NAME2+['정은정']
        elif '안대호' in item:
            NAME2=NAME2+['안대호']
        elif '안재영' in item:
            NAME2=NAME2+['안재영']
        elif '안중운' in item:
            NAME2=NAME2+['안중운']
        elif '안현진' in item:
            NAME2=NAME2+['안현진']
        elif '엄태인' in item:
            NAME2=NAME2+['엄태인']
        elif '우승윤' in item:
            NAME2=NAME2+['우승윤']
        elif '유미리' in item:
            NAME2=NAME2+['유미리']
        elif '유옥현' in item:
            NAME2=NAME2+['유옥현']
        elif '유희진' in item:
            NAME2=NAME2+['유희진']
        elif '윤경우' in item:
            NAME2=NAME2+['윤경우']
        elif '이가은' in item:
            NAME2=NAME2+['이가은']
        elif '이강정' in item:
            NAME2=NAME2+['이강정']
        elif '이경민' in item:
            NAME2=NAME2+['이경민']
        elif '이병철' in item:
            NAME2=NAME2+['이병철']
        elif '이서연' in item:
            NAME2=NAME2+['이서연']
        elif '이선민' in item:
            NAME2=NAME2+['이선민']
        elif '이승혜' in item:
            NAME2=NAME2+['이승혜']
        elif '이지민' in item:
            NAME2=NAME2+['이지민']
        elif '이지영' in item:
            NAME2=NAME2+['이지영']
        elif '이지현' in item:
            NAME2=NAME2+['이지현']
        elif '이진형' in item:
            NAME2=NAME2+['이진형']
        elif '이진희' in item:
            NAME2=NAME2+['이진희']
        elif '이현범' in item:
            NAME2=NAME2+['이현범']
        elif '이현주' in item:
            NAME2=NAME2+['이현주']
        elif '이혜경' in item:
            NAME2=NAME2+['이혜경']
        elif '이혜진' in item:
            NAME2=NAME2+['이혜진']
        elif '임수정' in item:
            NAME2=NAME2+['임수정']
        elif '작업자' in item:
            NAME2=NAME2+['작업자']
        elif '전성민' in item:
            NAME2=NAME2+['전성민']
        elif '조영태' in item:
            NAME2=NAME2+['조영태']
        elif '조은아' in item:
            NAME2=NAME2+['조은아']
        elif '조정민' in item:
            NAME2=NAME2+['조정민']
        elif '지원섭' in item:
            NAME2=NAME2+['지원섭']
        elif '지현민' in item:
            NAME2=NAME2+['지현민']
        elif '차명섭' in item:
            NAME2=NAME2+['차명섭']
        elif '채수지' in item:
            NAME2=NAME2+['채수지']
        elif '최다운' in item:
            NAME2=NAME2+['최다운']
        elif '최다혜' in item:
            NAME2=NAME2+['최다혜']
        elif '최미나' in item:
            NAME2=NAME2+['최미나']
        elif '최진섭' in item:
            NAME2=NAME2+['최진섭']
        elif '표현미' in item:
            NAME2=NAME2+['표현미']
        elif '표희주' in item:
            NAME2=NAME2+['표희주']
        elif '한봉구' in item:
            NAME2=NAME2+['한봉구']
        elif '한아름' in item:
            NAME2=NAME2+['한아름']
        elif '한지나' in item:
            NAME2=NAME2+['한지나']
        elif '허은' in item:
            NAME2=NAME2+['허은']
        elif '조상철' in item:
            NAME2=NAME2+['조상철']
        elif '이수정' in item:
            NAME2=NAME2+['이수정']
        elif '길리후' in item:
            NAME2=NAME2+['길리후']
        elif '김중섭' in item:
            NAME2=NAME2+['김중섭']
        elif '김지연' in item:
            NAME2=NAME2+['김지연']
        elif '박지녕' in item:
            NAME2=NAME2+['박지녕']
        elif '변규란' in item:
            NAME2=NAME2+['변규란']
        elif '서소연' in item:
            NAME2=NAME2+['서소연']
        elif '손여진' in item:
            NAME2=NAME2+['손여진']
        elif '손미나' in item:
            NAME2=NAME2+['손미나']
        elif '류창희' in item:
            NAME2=NAME2+['류창희']
        elif '서봉준' in item:
            NAME2=NAME2+['서봉준']
        elif '우경호' in item:
            NAME2=NAME2+['우경호']
        elif '정건화' in item:
            NAME2=NAME2+['정건화']
        elif '윤세은' in item:
            NAME2=NAME2+['윤세은']
        elif '하태성' in item:
            NAME2=NAME2+['하태성']
        elif '박경은' in item:
            NAME2=NAME2+['박경은']
        elif '박세리' in item:
            NAME2=NAME2+['박세리']
        elif '심미화' in item:
            NAME2=NAME2+['심미화']
        elif '이미연' in item:
            NAME2=NAME2+['이미연']
        elif '김샛별' in item:
            NAME2=NAME2+['김샛별']
        elif '조아라' in item:
            NAME2=NAME2+['조아라']
        elif '한용민' in item:
            NAME2=NAME2+['한용민']
        elif '김유진' in item:
            NAME2=NAME2+['김유진']
        elif '김학권' in item:
            NAME2=NAME2+['김학권']
        elif '전용준' in item:
            NAME2=NAME2+['전용준']
        elif '박기영' in item:
            NAME2=NAME2+['박기영']
        elif '유석기' in item:
            NAME2=NAME2+['유석기']
        elif '김봉현' in item:
            NAME2=NAME2+['김봉현']
        elif '심세희' in item:
            NAME2=NAME2+['심세희']
        elif '강영현' in item:
            NAME2=NAME2+['강영현']
        elif '신도현' in item:
            NAME2=NAME2+['신도현']
        elif '김나리' in item:
            NAME2=NAME2+['김나리']
        elif '홍대의' in item:
            NAME2=NAME2+['홍대의']
        elif '정진경' in item:
            NAME2=NAME2+['정진경']
        elif '민순홍' in item:
            NAME2=NAME2+['민순홍']
        elif '박경은' in item:
            NAME2=NAME2+['박경은']
        elif '오정아' in item:
            NAME2=NAME2+['오정아']
        elif '유수진' in item:
            NAME2=NAME2+['유수진']
        elif '이아현' in item:
            NAME2=NAME2+['이아현']
        elif '정주리' in item:
            NAME2=NAME2+['정주리']
        elif '윤희원' in item:
            NAME2=NAME2+['윤희원']
        elif '조성태' in item:
            NAME2=NAME2+['조성태']
        elif '박수홍' in item:
            NAME2=NAME2+['박수홍']
        elif '구희선' in item:
            NAME2=NAME2+['구희선']
        elif '임경미' in item:
            NAME2=NAME2+['임경미']
        elif '박지훈' in item:
            NAME2=NAME2+['박지훈']
        elif '남경민' in item:
            NAME2=NAME2+['남경민']
        elif '곽예지' in item:
            NAME2=NAME2+['곽예지']
        elif '김아영' in item:
            NAME2=NAME2+['김아영']
        elif '홍지은' in item:
            NAME2=NAME2+['홍지은']
        elif '이상희' in item:
            NAME2=NAME2+['이상희']
        elif '송가람' in item:
            NAME2=NAME2+['송가람']
        elif '전설화' in item:
            NAME2=NAME2+['전설화']
        elif '강은서' in item:
            NAME2=NAME2+['강은서']
        elif '김민지' in item:
            NAME2=NAME2+['김민지']
        elif '김송이' in item:
            NAME2=NAME2+['김송이']
        elif '김슬기' in item:
            NAME2=NAME2+['김슬기']
        elif '맹제은' in item:
            NAME2=NAME2+['맹제은']
        elif '박영균' in item:
            NAME2=NAME2+['박영균']
        elif '박준희' in item:
            NAME2=NAME2+['박준희']
        elif '배유진' in item:
            NAME2=NAME2+['배유진']
        elif '성남' in item:
            NAME2=NAME2+['김성남']
        elif '성수양' in item:
            NAME2=NAME2+['성수양']
        elif '송은지' in item:
            NAME2=NAME2+['송은지']
        elif '손종' in item:
            NAME2=NAME2+['손종식']
        elif '오차진' in item:
            NAME2=NAME2+['오차진']
        elif '우지영' in item:
            NAME2=NAME2+['우지영']
        elif '윤재은' in item:
            NAME2=NAME2+['윤재은']
        elif '이민지' in item:
            NAME2=NAME2+['이민지']
        elif '이석희' in item:
            NAME2=NAME2+['이석희']
        elif '임영순' in item:
            NAME2=NAME2+['임영순']
        elif '최일호' in item:
            NAME2=NAME2+['최일호']
        elif '효정' in item:
            NAME2=NAME2+['박효정']
        elif '김슬기' in item:
            NAME2=NAME2+['김슬기']
        elif '희주' in item:
            NAME2=NAME2+['표희주']
        elif '유호상' in item:
            NAME2=NAME2+['유호상']
        elif '공지영' in item:
            NAME2=NAME2+['공지영']
        elif '장경선' in item:
            NAME2=NAME2+['장경선']
        elif '이세정' in item:
            NAME2=NAME2+['이세정']
        elif '정지윤' in item:
            NAME2=NAME2+['정지윤']
        elif '맹제은' in item:
            NAME2=NAME2+['맹제은']
        elif '조영아' in item:
            NAME2=NAME2+['조영아']
        elif '손은지' in item:
            NAME2=NAME2+['송은지']
        elif '손진희' in item:
            NAME2=NAME2+['손진희']
        elif '지민선' in item:
            NAME2=NAME2+['지민선']
        elif '방승민' in item:
            NAME2=NAME2+['방승민']
        elif '김영선' in item:
            NAME2=NAME2+['김영선']
        elif '김준기' in item:
            NAME2=NAME2+['김준기']
        elif '유은하' in item:
            NAME2=NAME2+['유은하']
        elif '장윤주' in item:
            NAME2=NAME2+['장윤주']
        elif '정명옥' in item:
            NAME2=NAME2+['정명옥']
        elif '정다영' in item:
            NAME2=NAME2+['정다영']
        elif '조승호' in item:
            NAME2=NAME2+['조승호']
        elif '현영' in item:
            NAME2=NAME2+['현영']
        elif '김종학' in item:
            NAME2=NAME2+['김종학']
        elif '이효수' in item:
            NAME2=NAME2+['이효수']
        elif '홍시인' in item:
            NAME2=NAME2+['홍시인']
        elif '홍석우' in item:
            NAME2=NAME2+['홍석우']
        elif '정동호' in item:
            NAME2=NAME2+['정동호']
        elif '박정선' in item:
            NAME2=NAME2+['박정선']
        
        else:
            NAME2=NAME2+['?']

        
for i, name in enumerate(NAME2):
    print(name)
    ws1.Cells(i+2,3).Value = name
    
    
ex1.Save()
excel.Quit()
print("Done")
# Out:
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# 송은지
# 손진희
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# 장윤주
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# 지민선
# 방승민
# ?
# ?
# 김영선
# 김준기
# ?
# ?
# 유은하
# ?
# 장윤주
# 장윤주
# ?
# ?
# 정명옥
# 장윤주
# 장윤주
# ?
# ?
# ?
# ?
# 방승민
# ?
# 이효수
# 장윤주
# 정명옥
# ?
# ?
# ?
# 장윤주
# ?
# 장윤주
# ?
# ?
# ?
# 손진희
# ?
# 정다영
# 조승호
# 현영
# 현영
# 유은하
# ?
# ?
# 김종학
# ?
# 유은하
# ?
# 이효수
# 지민선
# ?
# ?
# ?
# ?
# 이효수
# 홍시인
# ?
# ?
# ?
# ?
# ?
# 홍석우
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# 정동호
# 장윤주
# ?
# 박정선
# ?
# 박정선
# ?
# 김준기
# 정다영
# 손진희
# ?
# ?
# ?
# ?
# 손진희
# 김준기
# ?
# ?
# ?
# ?
# 장윤주
# ?
# 방승민
# 손진희
# ?
# ?
# ?
# 박정선
# ?
# ?
# 정명옥
# ?
# ?
# ?
# ?
# 이효수
# ?
# ?
# ?
# 손진희
# ?
# ?
# ?
# 손진희
# ?
# 장윤주
# ?
# 이효수
# ?
# ?
# ?
# 김종학
# 김종학
# ?
# ?
# ?
# ?
# ?
# ?
# 강수지
# 강수지
# 강은서
# 강은서
# 강은서
# 공지영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# 공진영
# ...

# %%
print('a' in 'ABC')
print('A' in 'abc')
# Out:
# False
# False

# %%
import win32com.client as wc
excel = wc.Dispatch("Excel.Application")
ex1=excel.Workbooks.Open(r'C:\Users\uidk3482\Documents\project\임시사용\임시고장키워드.xlsx')
ws1= ex1.ActiveSheet

Name1=[]
NAME2=[]

for i in range(1,36247):
    Name1=Name1+[ws1.Cells(i,1).Value]
    
for item in Name1:
    
    #장비문제
    
    if '오븐' in item:
        NAME2=NAME2+['오븐']
    elif 'oven' in item:
        NAME2=NAME2+['오븐']

    elif '센서' in item:
        NAME2=NAME2+['센서']
    elif 'SENSOR' in item:
        NAME2=NAME2+['센서']
    elif 'sensor' in item:
        NAME2=NAME2+['센서']
    elif 'Sensor' in item:
        NAME2=NAME2+['센서']

    elif '값' in item:
        NAME2=NAME2+['파라미터']
    elif '파라미터' in item:
        NAME2=NAME2+['파라미터']
    elif 'parameter' in item:
        NAME2=NAME2+['파라미터']

    elif '광학센터링' in item:
        NAME2=NAME2+['광학센터링']

    elif '릴' in item:
        NAME2=NAME2+['릴']

    elif '그리드' in item:
        NAME2=NAME2+['그리드']
    elif 'grid' in item:
        NAME2=NAME2+['그리드']

    elif '구리스' in item:
        NAME2=NAME2+['구리스']

    elif '극성' in item:
        NAME2=NAME2+['극성']

    elif '클램프' in item:
        NAME2=NAME2+['클램프']

    elif '라벨' in item:
        NAME2=NAME2+['라벨']
    elif '글씨' in item:
        NAME2=NAME2+['라벨']
    elif '바코드' in item:
        NAME2=NAME2+['라벨']
    elif 'barc' in item:
        NAME2=NAME2+['라벨']
    elif 'Barc' in item:
        NAME2=NAME2+['라벨']

    elif '벨트' in item:
        NAME2=NAME2+['벨트']
    elif 'belt' in item:
        NAME2=NAME2+['벨트']

    elif '지그' in item:
        NAME2=NAME2+['지그']
    elif 'jig' in item:
        NAME2=NAME2+['지그']
    elif 'JIG' in item:
        NAME2=NAME2+['지그']
    elif 'ZIG' in item:
        NAME2=NAME2+['지그']

    elif '나사' in item:
        NAME2=NAME2+['나사']
    elif '볼트' in item:
        NAME2=NAME2+['나사']
    elif '너트' in item:
        NAME2=NAME2+['나사']

    elif '나이프' in item:
        NAME2=NAME2+['나이프']
    elif 'knife' in item:
        NAME2=NAME2+['나이프']

    elif '날개' in item:
        NAME2=NAME2+['날개']

    elif '납' in item:
        NAME2=NAME2+['납']

    elif '다이오드' in item:
        NAME2=NAME2+['다이오드']
    elif 'diode' in item:
        NAME2=NAME2+['다이오드']

    elif '노즐' in item:
        NAME2=NAME2+['노즐']
    elif 'noz' in item:
        NAME2=NAME2+['노즐']
    elif '노즈' in item:
        NAME2=NAME2+['노즐']
    elif 'NOZ' in item:
        NAME2=NAME2+['피더']

    elif '피더' in item:
        NAME2=NAME2+['피더']
    elif 'feeder' in item:
        NAME2=NAME2+['피더']
    elif 'FEED' in item:
        NAME2=NAME2+['피더']
    elif 'fider' in item:
        NAME2=NAME2+['피더']
    elif '피딩' in item:
        NAME2=NAME2+['피더']

    elif '청소' in item:
        NAME2=NAME2+['청소']
    elif 'clean' in item:
        NAME2=NAME2+['청소']

    elif '코팅' in item:
        NAME2=NAME2+['코팅']
    elif 'coating' in item:
        NAME2=NAME2+['코팅']

    elif '솔더' in item:
        NAME2=NAME2+['솔더']
    elif 'Solder' in item:
        NAME2=NAME2+['솔더']
    elif 'solder' in item:
        NAME2=NAME2+['솔더']

    elif '재시작' in item:
        NAME2=NAME2+['재시작']
    elif '장비전원리셋' in item:
        NAME2=NAME2+['재시작']
    elif 'RESET' in item:
        NAME2=NAME2+['재시작']
    elif 'Reset' in item:
        NAME2=NAME2+['재시작']
    elif 'reset' in item:
        NAME2=NAME2+['재시작']
    elif 'ON' in item:
        NAME2=NAME2+['재시작']
    elif 'On' in item:
        NAME2=NAME2+['재시작']
    elif 'on' in item:
        NAME2=NAME2+['재시작']
    elif 'OFF' in item:
        NAME2=NAME2+['재시작']
    elif 'off' in item:
        NAME2=NAME2+['재시작']
    elif '리셋' in item:
        NAME2=NAME2+['재시작']
    elif '초기화' in item:
        NAME2=NAME2+['재시작']

    elif '수동' in item:
        NAME2=NAME2+['수동']
    elif 'manual' in item:
        NAME2=NAME2+['수동']
    elif 'Manual' in item:
        NAME2=NAME2+['수동']

    elif '프로' in item:
        NAME2=NAME2+['프로그램']
    elif 'Prog' in item:
        NAME2=NAME2+['프로그램']
    elif 'prog' in item:
        NAME2=NAME2+['프로그램']
    elif '육안' in item:
        NAME2=NAME2+['육안']

    elif '케이블' in item:
        NAME2=NAME2+['케이블']
    elif '캐이블' in item:
        NAME2=NAME2+['케이블']
    elif 'Cable' in item:
        NAME2=NAME2+['케이블']
    elif 'cable' in item:
        NAME2=NAME2+['케이블']

    elif '픽업' in item:
        NAME2=NAME2+['픽업']
    elif 'pick' in item:
        NAME2=NAME2+['픽업']

    elif '모터' in item:
        NAME2=NAME2+['모터']
    elif 'motor' in item:
        NAME2=NAME2+['모터']
    elif 'Motor' in item:
        NAME2=NAME2+['모터']

    elif '이미지' in item:
        NAME2=NAME2+['이미지']
    elif 'image' in item:
        NAME2=NAME2+['이미지']

    elif '비전' in item:
        NAME2=NAME2+['비전']
    elif '비젼' in item:
        NAME2=NAME2+['비전']
    elif 'Visi' in item:
        NAME2=NAME2+['비전']
    elif 'visi' in item:
        NAME2=NAME2+['비전']

    elif '밸브' in item:
        NAME2=NAME2+['밸브']
    elif 'valve' in item:
        NAME2=NAME2+['밸브']
    elif 'valve' in item:
        NAME2=NAME2+['밸브']
    elif '벨브' in item:
        NAME2=NAME2+['벨브']

    elif '브러쉬' in item:
        NAME2=NAME2+['브러쉬']
    elif '브러시' in item:
        NAME2=NAME2+['브러쉬']
    elif 'brush' in item:
        NAME2=NAME2+['브러쉬']

    elif '챔버' in item:
        NAME2=NAME2+['챔버']
    elif 'chamber' in item:
        NAME2=NAME2+['챔버']

    elif '파레트' in item:
        NAME2=NAME2+['파레트']
    elif '파렛트' in item:
        NAME2=NAME2+['파레트']
    elif '팔레트' in item:
        NAME2=NAME2+['파레트']
    elif '빠레트' in item:
        NAME2=NAME2+['파레트']
    elif '빠렛트' in item:
        NAME2=NAME2+['파레트']

    elif '판넬' in item:
        NAME2=NAME2+['판넬']
    elif 'pan' in item:
        NAME2=NAME2+['판넬']

    elif '코일' in item:
        NAME2=NAME2+['코일']
    elif 'coil' in item:
        NAME2=NAME2+['코일']

    elif '컨베이어' in item:
        NAME2=NAME2+['컨베이어']
    elif 'conv' in item:
        NAME2=NAME2+['컨베이어']

    elif '커버' in item:
        NAME2=NAME2+['커버']
    elif 'cover' in item:
        NAME2=NAME2+['커버']

    elif '캐리어' in item:
        NAME2=NAME2+['캐리어']
    elif 'carrier' in item:
        NAME2=NAME2+['캐리어']

    elif '컨트롤' in item:
        NAME2=NAME2+['컨트롤']
    elif 'contr' in item:
        NAME2=NAME2+['컨트롤']

    elif '클램퍼' in item:
        NAME2=NAME2+['클램퍼']
    elif '클램프' in item:
        NAME2=NAME2+['클램퍼']
    elif 'clamp' in item:
        NAME2=NAME2+['클램퍼']
    
    elif '클린칭' in item:
        NAME2=NAME2+['클린칭']
    elif 'clin' in item:
        NAME2=NAME2+['클린칭']

    elif '톱니' in item:
        NAME2=NAME2+['톱니']

    elif '투입' in item:
        NAME2=NAME2+['투입']

    elif '패드' in item:
        NAME2=NAME2+['패드']
    elif 'pad' in item:
        NAME2=NAME2+['패드']

    elif '폭' in item:
        NAME2=NAME2+['폭']

    elif '퓨즈' in item:
        NAME2=NAME2+['퓨즈']
    elif 'fuse' in item:
        NAME2=NAME2+['퓨즈']

    elif '프린터' in item:
        NAME2=NAME2+['프린터']
    elif 'print' in item:
        NAME2=NAME2+['프린터']

    elif '플럭스' in item:
        NAME2=NAME2+['플럭스']
    elif 'flux' in item:
        NAME2=NAME2+['플럭스']

    elif '하우징' in item:
        NAME2=NAME2+['하우징']
    elif 'Hous' in item:
        NAME2=NAME2+['하우징']
    elif 'hous' in item:
        NAME2=NAME2+['하우징']

    elif '피듀셜' in item:
        NAME2=NAME2+['피두셜']
    elif '피두셜' in item:
        NAME2=NAME2+['피두셜']
    elif 'fidu' in item:
        NAME2=NAME2+['피두셜']
    elif '피듀설' in item:
        NAME2=NAME2+['피두셜']
    elif 'Fidu' in item:
        NAME2=NAME2+['피두셜']

    elif '플런져' in item:
        NAME2=NAME2+['플런져']
    elif '플런저' in item:
        NAME2=NAME2+['플런져']
    elif '플란저' in item:
        NAME2=NAME2+['플런져']
    elif '플란져' in item:
        NAME2=NAME2+['플런져']
    elif 'Plung' in item:
        NAME2=NAME2+['플런져']
    elif 'plung' in item:
        NAME2=NAME2+['플런져']
    elif 'pLUNG' in item:
        NAME2=NAME2+['플런져']
    elif 'PLUNG' in item:
        NAME2=NAME2+['플런져']

    elif '소켓' in item:
        NAME2=NAME2+['소켓']
    elif 'SOCK' in item:
        NAME2=NAME2+['소켓']
    elif 'sock' in item:
        NAME2=NAME2+['소켓']
    elif 'Sock' in item:
        NAME2=NAME2+['소켓']

    elif '렉' in item:
        NAME2=NAME2+['렉']
    elif '랙' in item:
        NAME2=NAME2+['렉']
    elif 'wra' in item:
        NAME2=NAME2+['렉']

    elif '진공' in item:
        NAME2=NAME2+['베큠']
    elif '베큠' in item:
        NAME2=NAME2+['베큠']
    elif 'vacc' in item:
        NAME2=NAME2+['베큠']
    elif 'Vacc' in item:
        NAME2=NAME2+['베큠']

    elif '호일' in item:
        NAME2=NAME2+['호일']
    elif '포일' in item:
        NAME2=NAME2+['호일']
    elif 'foil' in item:
        NAME2=NAME2+['호일']
    elif 'Foil' in item:
        NAME2=NAME2+['호일']

    elif '세그먼트' in item:
        NAME2=NAME2+['세그먼트']
    elif 'segm' in item:
        NAME2=NAME2+['세그먼트']
    elif 'SEGM' in item:
        NAME2=NAME2+['세그먼트']
    elif 'Segm' in item:
        NAME2=NAME2+['세그먼트']

    elif '스크류' in item:
        NAME2=NAME2+['스크류']
    elif 'Screw' in item:
        NAME2=NAME2+['스크류']
    elif 'screw' in item:
        NAME2=NAME2+['스크류']

    elif '스텐실' in item:
        NAME2=NAME2+['스텐실']
    elif 'stenc' in item:
        NAME2=NAME2+['스텐실']
    elif 'Stenc' in item:
        NAME2=NAME2+['스텐실']

    elif '실리콘' in item:
        NAME2=NAME2+['실리콘']
    elif 'sili' in item:
        NAME2=NAME2+['실리콘']
    elif 'Sili' in item:
        NAME2=NAME2+['실리콘']

    elif '진동' in item:
        NAME2=NAME2+['진동']
    elif '바이브' in item:
        NAME2=NAME2+['진동']
    elif 'vibr' in item:
        NAME2=NAME2+['진동']
    elif 'vivr' in item:
        NAME2=NAME2+['진동']
    elif 'vive' in item:
        NAME2=NAME2+['진동']
        
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    
    
    
    
    ##제품문제   
    elif '긁힘 item:
        NAME2=NAME2+['긁힘']

    elif '뒤집힘' in item:
        NAME2=NAME2+['뒤집힘']

    elif '가불량' in item:
        NAME2=NAME2+['가불량']
    elif 'NTF' in item:
        NAME2=NAME2+['가불량']
    elif 'ntf' in item:
        NAME2=NAME2+['가불량']

    elif '통신' in item:
        NAME2=NAME2+['통신']

    elif '쇼트' in item:
        NAME2=NAME2+['쇼트']
    elif 'Short' in item:
        NAME2=NAME2+['쇼트']
    elif 'short' in item:
        NAME2=NAME2+['쇼트']

    elif '들뜸' in item:
        NAME2=NAME2+['들뜸']
    elif 'lift' in item:
        NAME2=NAME2+['들뜸']
        
    elif '비석' in item:
        NAME2=NAME2+['비석']
        
    elif '틀어짐' in item:
        NAME2=NAME2+['틀어짐']
        
    elif '날림' in item:
        NAME2=NAME2+['날림']
        
    elif '까임' in item:
        NAME2=NAME2+['까임']
    
    elif '미실장' in item:
        NAME2=NAME2+['미실장']
        
        
    elif '콘덴서' in item:
        NAME2=NAME2+['콘덴서']
    elif 'conden' in item:
        NAME2=NAME2+['콘덴서']
    elif '캐패시' in item:
        NAME2=NAME2+['콘덴서']
    elif 'capaci' in item:
        NAME2=NAME2+['콘덴서']
    elif '케페 in item:
        NAME2=NAME2+['콘덴서']
    elif 'Capaci' in item:
        NAME2=NAME2+['콘덴서']
        
    elif '제품' in item:
        NAME2=NAME2+['제품']

    elif '기포' in item:
        NAME2=NAME2+['기포']
    elif '보이드' in item:
        NAME2=NAME2+['기포']
    elif 'void' in item:
        NAME2=NAME2+['기포']

    elif 'PCB' in item:
        NAME2=NAME2+['PCB']
    elif 'pcb' in item:
        NAME2=NAME2+['pcb']

    elif '칩' in item:
        NAME2=NAME2+['칩']
    elif 'chip' in item:
        NAME2=NAME2+['칩']
    elif 'Chip' in item:
        NAME2=NAME2+['칩']
    elif 'CHIP' in item:
        NAME2=NAME2+['칩']    
        
    elif '자재' in item:
        NAME2=NAME2+['자재']
    elif '자제' in item:
        NAME2=NAME2+['자재']

    elif '커넥터' in item:
        NAME2=NAME2+['커넥터']
    elif '컨넥터' in item:
        NAME2=NAME2+['커넥터']
    elif 'connect' in item:
        NAME2=NAME2+['커넥터']
    elif 'Connect' in item:
        NAME2=NAME2+['커넥터']
    elif '' in item:
        NAME2=NAME2+['커넥터']
        
    elif '로드러너' in item:
        NAME2=NAME2+['로드러너']
    elif 'road' in item:
        NAME2=NAME2+['로드러너']
    elif 'runner' in item:
        NAME2=NAME2+['로드러너']
    elif 'Runner' in item:
        NAME2=NAME2+['로드러너']
    elif 'Road' in item:
        NAME2=NAME2+['로드러너']
    elif '로드 러너' in item:
        NAME2=NAME2+['로드러너']
        
    elif '핀' in item:
        NAME2=NAME2+['핀']
    elif 'Pin' in item:
        NAME2=NAME2+['핀']
    elif 'PIN' in item:
        NAME2=NAME2+['핀']
    elif 'pin' in item:
        NAME2=NAME2+['핀']
        
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    elif '' in item:
        NAME2=NAME2+['']
    else:
        NAME2=NAME2+['?']

        
for i, name in enumerate(NAME2):
    print(name)
    ws1.Cells(i+1,3).Value = name
    
    
ex1.Save()
excel.Quit()
print("Done")
# Out:
# 밥
# True
# True
# 많이
# True
